# %% [markdown]
# <a href="https://colab.research.google.com/github/Ashiskumargit/Divine-AI-Data-Science/blob/main/TS/1_Time_Series_ARIMA_Electric_Production_US_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 15, 6
data = pd.read_csv("Electric_Production.csv",index_col=0)
data.head()
# Out:
#             IPG2211A2N
# DATE
# 1939-01-01      3.3842
# 1939-02-01      3.4100
# 1939-03-01      3.4875
# 1939-04-01      3.5133
# 1939-05-01      3.5133

# %%
# We now convert this data into a time series data. Currently the date values are stored as string type.

# %%
data.index
# Out:
# Index(['1939-01-01', '1939-02-01', '1939-03-01', '1939-04-01', '1939-05-01',
#        '1939-06-01', '1939-07-01', '1939-08-01', '1939-09-01', '1939-10-01',
#        ...
#        '2017-09-01', '2017-10-01', '2017-11-01', '2017-12-01', '2018-01-01',
#        '2018-02-01', '2018-03-01', '2018-04-01', '2018-05-01', '2018-06-01'],
#       dtype='object', name='DATE', length=954)

# %%
data.index = pd.to_datetime(data.index)

# %%
data.head()
# Out:
#             IPG2211A2N
# DATE
# 1939-01-01      3.3842
# 1939-02-01      3.4100
# 1939-03-01      3.4875
# 1939-04-01      3.5133
# 1939-05-01      3.5133

# %%
data.index
# Out:
# DatetimeIndex(['1939-01-01', '1939-02-01', '1939-03-01', '1939-04-01',
#                '1939-05-01', '1939-06-01', '1939-07-01', '1939-08-01',
#                '1939-09-01', '1939-10-01',
#                ...
#                '2017-09-01', '2017-10-01', '2017-11-01', '2017-12-01',
#                '2018-01-01', '2018-02-01', '2018-03-01', '2018-04-01',
#                '2018-05-01', '2018-06-01'],
#               dtype='datetime64[ns]', name='DATE', length=954, freq=None)

# %%
# Check for missing data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 954 entries, 1939-01-01 to 2018-06-01
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   IPG2211A2N  954 non-null    float64
# dtypes: float64(1)
# memory usage: 14.9 KB

# %%
# Rename column for ease

# %%
data.columns = ['energy_prod']

# %%
data.head()
# Out:
#             energy_prod
# DATE
# 1939-01-01       3.3842
# 1939-02-01       3.4100
# 1939-03-01       3.4875
# 1939-04-01       3.5133
# 1939-05-01       3.5133

# %%
pip install statsmodels
# Out:
# Collecting statsmodelsNote: you may need to restart the kernel to use updated packages.
#   Downloading statsmodels-0.13.1-cp38-cp38-win_amd64.whl (9.1 MB)
# Collecting patsy>=0.5.2
#   Downloading patsy-0.5.2-py2.py3-none-any.whl (233 kB)
# Requirement already satisfied: numpy>=1.17 in c:\users\bhagat\anaconda3\envs\ashis\lib\site-packages (from statsmodels) (1.21.5)
# Requirement already satisfied: scipy>=1.3 in c:\users\bhagat\anaconda3\envs\ashis\lib\site-packages (from statsmodels) (1.7.3)
# Requirement already satisfied: pandas>=0.25 in c:\users\bhagat\anaconda3\envs\ashis\lib\site-packages (from statsmodels) (1.3.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\bhagat\anaconda3\envs\ashis\lib\site-packages (from pandas>=0.25->statsmodels) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\bhagat\anaconda3\envs\ashis\lib\site-packages (from pandas>=0.25->statsmodels) (2021.3)
# Requirement already satisfied: six in c:\users\bhagat\anaconda3\envs\ashis\lib\site-packages (from patsy>=0.5.2->statsmodels) (1.16.0)
#
# Installing collected packages: patsy, statsmodels
# Successfully installed patsy-0.5.2 statsmodels-0.13.1

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
decomposition = seasonal_decompose(data)

trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

# %%
plt.subplot(411)
plt.plot(data, label='Original')
plt.legend(loc='best')

plt.subplot(412)
plt.plot(trend, label='Trend')
plt.legend(loc='best')

plt.subplot(413)
plt.plot(seasonal,label='Seasonality')
plt.legend(loc='best')

plt.subplot(414)
plt.plot(residual, label='Residuals')
plt.legend(loc='best')
plt.tight_layout()

# %%
data.shape
# Out:
# (954, 1)

# %%
pip install pmdarima
# Out:
# Collecting pmdarimaNote: you may need to restart the kernel to use updated packages.
#   Downloading pmdarima-1.8.4-cp38-cp38-win_amd64.whl (600 kB)
# Requirement already satisfied: urllib3 in c:\users\bhagat\anaconda3\envs\ashis\lib\site-packages (from pmdarima) (1.26.8)
# Requirement already satisfied: pandas>=0.19 in c:\users\bhagat\anaconda3\envs\ashis\lib\site-packages (from pmdarima) (1.3.5)
# Collecting Cython!=0.29.18,>=0.29
#   Downloading Cython-0.29.26-py2.py3-none-any.whl (983 kB)
# Requirement already satisfied: numpy>=1.19.3 in c:\users\bhagat\anaconda3\envs\ashis\lib\site-packages (from pmdarima) (1.21.5)
# Requirement already satisfied: joblib>=0.11 in c:\users\bhagat\anaconda3\envs\ashis\lib\site-packages (from pmdarima) (1.1.0)
# Requirement already satisfied: scikit-learn>=0.22 in c:\users\bhagat\anaconda3\envs\ashis\lib\site-packages (from pmdarima) (1.0.2)
# Requirement already satisfied: statsmodels!=0.12.0,>=0.11 in c:\users\bhagat\anaconda3\envs\ashis\lib\site-packages (from pmdarima) (0.13.1)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in c:\users\bhagat\anaconda3\envs\ashis\lib\site-packages (from pmdarima) (58.0.4)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\bhagat\anaconda3\envs\ashis\lib\site-packages (from pmdarima) (1.7.3)
# Requirement already satisfied: pytz>=2017.3 in c:\users\bhagat\anaconda3\envs\ashis\lib\site-packages (from pandas>=0.19->pmdarima) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\bhagat\anaconda3\envs\ashis\lib\site-packages (from pandas>=0.19->pmdarima) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\bhagat\anaconda3\envs\ashis\lib\site-packages (from python-dateutil>=2.7.3->pandas>=0.19->pmdarima) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\bhagat\anaconda3\envs\ashis\lib\site-packages (from scikit-learn>=0.22->pmdarima) (3.0.0)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\bhagat\anaconda3\envs\ashis\lib\site-packages (from statsmodels!=0.12.0,>=0.11->pmdarima) (0.5.2)
# Installing collected packages: Cython, pmdarima
# Successfully installed Cython-0.29.26 pmdarima-1.8.4

# %%
from pmdarima.arima import auto_arima
stepwise_model = auto_arima(data, start_p=1, start_q=1,
                           max_p=3, max_q=3, m=12,
                           start_P=0, seasonal=True,
                           d=1, D=1, trace=True,
                           error_action='ignore',  
                           suppress_warnings=True, 
                           stepwise=True)
print(stepwise_model.aic())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,1,1)[12]             : AIC=3729.023, Time=3.74 sec
#  ARIMA(0,1,0)(0,1,0)[12]             : AIC=4226.662, Time=0.25 sec
#  ARIMA(1,1,0)(1,1,0)[12]             : AIC=4048.141, Time=1.10 sec
#  ARIMA(0,1,1)(0,1,1)[12]             : AIC=3850.307, Time=1.69 sec
#  ARIMA(1,1,1)(0,1,0)[12]             : AIC=inf, Time=1.50 sec
#  ARIMA(1,1,1)(1,1,1)[12]             : AIC=3728.477, Time=4.49 sec
#  ARIMA(1,1,1)(1,1,0)[12]             : AIC=3890.232, Time=2.94 sec
#  ARIMA(1,1,1)(2,1,1)[12]             : AIC=3705.062, Time=8.06 sec
#  ARIMA(1,1,1)(2,1,0)[12]             : AIC=3775.519, Time=5.83 sec
#  ARIMA(1,1,1)(2,1,2)[12]             : AIC=3690.617, Time=22.65 sec
#  ARIMA(1,1,1)(1,1,2)[12]             : AIC=3722.200, Time=13.78 sec
#  ARIMA(0,1,1)(2,1,2)[12]             : AIC=3789.730, Time=17.68 sec
#  ARIMA(1,1,0)(2,1,2)[12]             : AIC=3832.019, Time=18.50 sec
#  ARIMA(2,1,1)(2,1,2)[12]             : AIC=3690.547, Time=24.48 sec
#  ARIMA(2,1,1)(1,1,2)[12]             : AIC=3718.849, Time=19.26 sec
#  ARIMA(2,1,1)(2,1,1)[12]             : AIC=3701.513, Time=12.36 sec
#  ARIMA(2,1,1)(1,1,1)[12]             : AIC=3725.593, Time=6.59 sec
#  ARIMA(2,1,0)(2,1,2)[12]             : AIC=3769.261, Time=21.65 sec
#  ARIMA(3,1,1)(2,1,2)[12]             : AIC=3687.480, Time=23.21 sec
#  ARIMA(3,1,1)(1,1,2)[12]             : AIC=3715.432, Time=21.89 sec
#  ARIMA(3,1,1)(2,1,1)[12]             : AIC=3698.356, Time=13.39 sec
#  ARIMA(3,1,1)(1,1,1)[12]             : AIC=3722.031, Time=10.40 sec
#  ARIMA(3,1,0)(2,1,2)[12]             : AIC=3762.332, Time=20.74 sec
#  ARIMA(3,1,2)(2,1,2)[12]             : AIC=3688.154, Time=36.28 sec
#  ARIMA(2,1,2)(2,1,2)[12]             : AIC=3688.924, Time=26.57 sec
#  ARIMA(3,1,1)(2,1,2)[12] intercept   : AIC=3693.496, Time=63.22 sec
#
# Best model:  ARIMA(3,1,1)(2,1,2)[12]
# Total fit time: 402.937 seconds
# 3687.480348021375

# %%
stepwise_model.aic()
# Out:
# 3687.480348021375

# %%
# Convert data to stationary time series

data2 = np.log(data)

# %%
# Train Test Split Data

# %%
data2.head()
# Out:
#             energy_prod
# DATE
# 1939-01-01     1.219118
# 1939-02-01     1.226712
# 1939-03-01     1.249185
# 1939-04-01     1.256556
# 1939-05-01     1.256556

# %%
data2.tail()
# Out:
#             energy_prod
# DATE
# 2018-02-01     4.672881
# 2018-03-01     4.638972
# 2018-04-01     4.534820
# 2018-05-01     4.548848
# 2018-06-01     4.652571

# %%
train = data2.loc['1939-01-01':'2016-12-01']
test = data2.loc['2017-01-01':]

# %%
train.tail()
# Out:
#             energy_prod
# DATE
# 2016-08-01     4.749101
# 2016-09-01     4.626763
# 2016-10-01     4.507477
# 2016-11-01     4.524756
# 2016-12-01     4.729683

# %%
test.head()
# Out:
#             energy_prod
# DATE
# 2017-01-01     4.745888
# 2017-02-01     4.592996
# 2017-03-01     4.609001
# 2017-04-01     4.460350
# 2017-05-01     4.502331

# %%
test.tail()
# Out:
#             energy_prod
# DATE
# 2018-02-01     4.672881
# 2018-03-01     4.638972
# 2018-04-01     4.534820
# 2018-05-01     4.548848
# 2018-06-01     4.652571

# %%
len(test)
# Out:
# 18

# %%
stepwise_model.fit(train)
# Out:
# ARIMA(order=(3, 1, 1), scoring_args={}, seasonal_order=(2, 1, 2, 12),
#       suppress_warnings=True, with_intercept=False)

# %%
future_forecast = stepwise_model.predict(n_periods=18)

# %%
future_forecast
# Out:
# array([4.8305472 , 4.73013662, 4.62632785, 4.52281763, 4.54385513,
#        4.66799891, 4.75720523, 4.75574621, 4.65011177, 4.54861868,
#        4.58223534, 4.73693154, 4.83347613, 4.75001701, 4.65226949,
#        4.54007358, 4.5594115 , 4.68156811])

# %%
future_forecast = pd.DataFrame(future_forecast,index = test.index,columns=['Prediction'])

future_forecast.head()
# Out:
#             Prediction
# DATE
# 2017-01-01    4.830547
# 2017-02-01    4.730137
# 2017-03-01    4.626328
# 2017-04-01    4.522818
# 2017-05-01    4.543855

# %%
test.head()
# Out:
#             energy_prod
# DATE
# 2017-01-01     4.745888
# 2017-02-01     4.592996
# 2017-03-01     4.609001
# 2017-04-01     4.460350
# 2017-05-01     4.502331

# %%
pd.concat([test,future_forecast],axis=1).plot()
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
future_forecast2 = np.exp(future_forecast)

# %%
pd.concat([data,future_forecast2],axis=1).plot()
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
#Check r2 score for accuracy of prediction

# %%
from sklearn.metrics import r2_score
r2_score(np.exp(test),future_forecast2)
# Out:
# 0.6482514289778478
